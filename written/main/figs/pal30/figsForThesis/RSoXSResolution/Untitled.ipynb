# %%
# %run commensurate.py
# %matplotlib inline
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /mnt/d/Dropbox/Films/PAL30/PAL30/pal30rep/paper/figs/suppfigs/commensurate/commensurate.py in <module>()
#      27 #read in data:
#      28 data = pd.read_csv('./xrayfrommikesaxsrsoxs.dat',na_values='--',sep=',',dtype=np.float64,skiprows=2,names=['TempR2','dR2','TempR3','dR3','TempS','dS'])
# ---> 29 data.drop(0,inplace=True) #drop the comments line
#      30 #now, divide each d from the fundamental
#      31 data['rx3'] =pd.to_numeric(data['d.1'].dropna())/pd.to_numeric(data['d.2'])
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    3692                                            index=index, columns=columns,
#    3693                                            level=level, inplace=inplace,
# ...

# %%
plt.plot(data['T'],data['d'],'.')
plt.plot(data['T.1'],data['d.1'],'.')

# %%
plt.plot(pd.to_numeric(data['T.2'].iloc[::5],data['d.2'].iloc[::5],'.')

# %%
plt.plot(pd.to_numeric(data['T.2']))
